# %%
import pandas as pd
import statistics as stats

# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/file/d/1U6YrTylJYy2OIg386YfgeUHvyg17Jptf/view?usp=sharing'

fluff, id = link.split('=')
print (id) # Verify that you have everything after '='
id = '1U6YrTylJYy2OIg386YfgeUHvyg17Jptf'

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('LekagulSensorData.csv.csv')  
df3 = pd.read_csv('LekagulSensorData.csv.csv')
# Out:
# sharing

# %%
df3
# Out:
#                   Timestamp              car-id car-type      gate-name
# 0       2015-05-01 00:43:28  20154301124328-262        4      entrance3
# 1       2015-05-01 01:03:48  20154301124328-262        4  general-gate1
# 2       2015-05-01 01:06:24  20154301124328-262        4   ranger-stop2
# 3       2015-05-01 01:09:25  20154301124328-262        4   ranger-stop0
# 4       2015-05-01 01:12:36  20154301124328-262        4  general-gate2
# ...                     ...                 ...      ...            ...
# 171472  2016-05-31 23:40:13  20161031111001-854        6   ranger-stop2
# 171473  2016-05-31 23:42:08  20165831105856-579        1  general-gate4
# 171474  2016-05-31 23:43:13  20161031111001-854        6  general-gate1
# 171475  2016-05-31 23:49:45  20165831105856-579        1  general-gate7
# 171476  2016-05-31 23:56:06  20161031111001-854        6  general-gate4
#
# [171477 rows x 4 columns]

# %%
df3['Timestamp'] = pd.to_datetime(df3['Timestamp'])
df3['Timestamp']
df3['year'], df3['month'] = df3['Timestamp'].dt.year, df3['Timestamp'].dt.month
df3['gateX'] = 0
df3['gateY'] = 0
df3 = df3.rename(columns={'gate-name': 'gate'})
df3.loc[df3.gate == "ranger-stop1", 'gateX'] = 20
df3.loc[df3.gate == "ranger-stop1", 'gateY'] = 175

df3.loc[df3.gate == "entrance0", 'gateX'] = 63
df3.loc[df3.gate == "entrance0", 'gateY'] = 186

df3.loc[df3.gate == "ranger-stop0", 'gateX'] = 80
df3.loc[df3.gate == "ranger-stop0", 'gateY'] = 183

df3.loc[df3.gate == "general-gate0", 'gateX'] = 111
df3.loc[df3.gate == "general-gate0", 'gateY'] = 190

df3.loc[df3.gate == "general-gate1", 'gateX'] = 65
df3.loc[df3.gate == "general-gate1", 'gateY'] = 174

df3.loc[df3.gate == "gate0", 'gateX'] = 64
df3.loc[df3.gate == "gate0", 'gateY'] = 166

df3.loc[df3.gate == "ranger-stop2", 'gateX'] = 64
df3.loc[df3.gate == "ranger-stop2", 'gateY'] = 166

df3.loc[df3.gate == "general-gate2", 'gateX'] = 105
df3.loc[df3.gate == "general-gate2", 'gateY'] = 167

df3.loc[df3.gate == "camping0", 'gateX'] = 53
df3.loc[df3.gate == "camping0", 'gateY'] = 158

df3.loc[df3.gate == "gate1", 'gateX'] = 59
df3.loc[df3.gate == "gate1", 'gateY'] = 155

df3.loc[df3.gate == "camping1", 'gateX'] = 130
df3.loc[df3.gate == "camping1", 'gateY'] = 149

df3.loc[df3.gate == "ranger-stop3", 'gateX'] = 149
df3.loc[df3.gate == "ranger-stop3", 'gateY'] = 154

df3.loc[df3.gate == "ranger-stop3", 'gateX'] = 149
df3.loc[df3.gate == "ranger-stop3", 'gateY'] = 154

df3.loc[df3.gate == "camping8", 'gateX'] = 184
df3.loc[df3.gate == "camping8", 'gateY'] = 151

df3.loc[df3.gate == "gate2", 'gateX'] = 25
df3.loc[df3.gate == "gate2", 'gateY'] = 145

df3.loc[df3.gate == "gate2", 'gateX'] = 25
df3.loc[df3.gate == "gate2", 'gateY'] = 145

df3.loc[df3.gate == "entrance1", 'gateX'] = 18
df3.loc[df3.gate == "entrance1", 'gateY'] = 132

df3.loc[df3.gate == "camping2", 'gateX'] = 45
df3.loc[df3.gate == "camping2", 'gateY'] = 135

df3.loc[df3.gate == "camping3", 'gateX'] = 46
df3.loc[df3.gate == "camping3", 'gateY'] = 131

df3.loc[df3.gate == "gate3", 'gateX'] = 150
df3.loc[df3.gate == "gate3", 'gateY'] = 139

df3.loc[df3.gate == "ranger-stop4", 'gateX'] = 19
df3.loc[df3.gate == "ranger-stop4", 'gateY'] = 104

df3.loc[df3.gate == "camping4", 'gateX'] = 49
df3.loc[df3.gate == "camping4", 'gateY'] = 110

df3.loc[df3.gate == "general-gate4", 'gateX'] = 70
df3.loc[df3.gate == "general-gate4", 'gateY'] = 101

df3.loc[df3.gate == "general-gate5", 'gateX'] = 125
df3.loc[df3.gate == "general-gate5", 'gateY'] = 88

df3.loc[df3.gate == "entrance2", 'gateX'] = 184
df3.loc[df3.gate == "entrance2", 'gateY'] = 112

df3.loc[df3.gate == "camping5", 'gateX'] = 21
df3.loc[df3.gate == "camping5", 'gateY'] = 78

df3.loc[df3.gate == "ranger-stop5", 'gateX'] = 152
df3.loc[df3.gate == "ranger-stop5", 'gateY'] = 81

df3.loc[df3.gate == "gate4", 'gateX'] = 165
df3.loc[df3.gate == "gate4", 'gateY'] = 85

df3.loc[df3.gate == "general-gate7", 'gateX'] = 66
df3.loc[df3.gate == "general-gate7", 'gateY'] = 55

df3.loc[df3.gate == "ranger-stop7", 'gateX'] = 101
df3.loc[df3.gate == "ranger-stop7", 'gateY'] = 47

df3.loc[df3.gate == "gate7", 'gateX'] = 98
df3.loc[df3.gate == "gate7", 'gateY'] = 39

df3.loc[df3.gate == "gate6", 'gateX'] = 117
df3.loc[df3.gate == "gate6", 'gateY'] = 48

df3.loc[df3.gate == "ranger-stop6", 'gateX'] = 124
df3.loc[df3.gate == "ranger-stop6", 'gateY'] = 52

df3.loc[df3.gate == "gate5", 'gateX'] = 132
df3.loc[df3.gate == "gate5", 'gateY'] = 53

df3.loc[df3.gate == "general-gate6", 'gateX'] = 137
df3.loc[df3.gate == "general-gate6", 'gateY'] = 62

df3.loc[df3.gate == "camping7", 'gateX'] = 182
df3.loc[df3.gate == "camping7", 'gateY'] = 54

df3.loc[df3.gate == "entrance3", 'gateX'] = 137
df3.loc[df3.gate == "entrance3", 'gateY'] = 32

df3.loc[df3.gate == "ranger-base", 'gateX'] = 129
df3.loc[df3.gate == "ranger-base", 'gateY'] = 24

df3.loc[df3.gate == "gate8", 'gateX'] = 139
df3.loc[df3.gate == "gate8", 'gateY'] = 18

df3.loc[df3.gate == "entrance4", 'gateX'] = 141
df3.loc[df3.gate == "entrance4", 'gateY'] = 15

df3.loc[df3.gate == "camping6", 'gateX'] = 151
df3.loc[df3.gate == "camping6", 'gateY'] = 22

df3 = df3.rename(columns={'car-type': 'ctype'})
df3.loc[df3.ctype == "2P", 'ctype'] = 7

# %%
df3.loc[df3.month == 5, 'monthOrder'] = 1
df3.loc[df3.month == 6, 'monthOrder'] = 2
df3.loc[df3.month == 7, 'monthOrder'] = 3
df3.loc[df3.month == 8, 'monthOrder'] = 4
df3.loc[df3.month == 9, 'monthOrder'] = 5
df3.loc[df3.month == 10, 'monthOrder'] = 6
df3.loc[df3.month == 11, 'monthOrder'] = 7
df3.loc[df3.month == 12, 'monthOrder'] = 8
df3.loc[df3.month == 1, 'monthOrder'] = 9
df3.loc[df3.month == 2, 'monthOrder'] = 10
df3.loc[df3.month == 3, 'monthOrder'] = 11
df3.loc[df3.month == 4, 'monthOrder'] = 12

df3.loc[df3.ctype == 5, 'monthOrder'] = 1

# %%
df3.loc[df3.gate == "ranger-stop1", 'gateType'] = 4

df3.loc[df3.gate == "entrance0", 'gateType'] = 1


df3.loc[df3.gate == "ranger-stop0", 'gateType'] = 4

df3.loc[df3.gate == "general-gate0", 'gateType'] = 2

df3.loc[df3.gate == "general-gate1", 'gateType'] = 2


df3.loc[df3.gate == "gate0", 'gateType'] = 3


df3.loc[df3.gate == "ranger-stop2", 'gateType'] = 4


df3.loc[df3.gate == "general-gate2", 'gateType'] = 2


df3.loc[df3.gate == "camping0", 'gateType'] = 5


df3.loc[df3.gate == "gate1", 'gateType'] = 3


df3.loc[df3.gate == "camping1", 'gateType'] = 5


df3.loc[df3.gate == "ranger-stop3", 'gateType'] = 4


df3.loc[df3.gate == "ranger-stop3", 'gateType'] = 4

df3.loc[df3.gate == "camping8", 'gateType'] = 5


df3.loc[df3.gate == "gate2", 'gateType'] = 3

df3.loc[df3.gate == "gate2", 'gateType'] = 3

df3.loc[df3.gate == "entrance1", 'gateType'] = 1

df3.loc[df3.gate == "camping2", 'gateType'] = 5

df3.loc[df3.gate == "camping3", 'gateType'] = 5

df3.loc[df3.gate == "gate3", 'gateType'] = 3

df3.loc[df3.gate == "ranger-stop4", 'gateType'] = 4

df3.loc[df3.gate == "camping4", 'gateType'] = 3

df3.loc[df3.gate == "general-gate4", 'gateType'] = 2

df3.loc[df3.gate == "general-gate5", 'gateType'] = 2

df3.loc[df3.gate == "entrance2", 'gateType'] = 1

df3.loc[df3.gate == "camping5", 'gateType'] = 1

df3.loc[df3.gate == "ranger-stop5", 'gateType'] = 4

df3.loc[df3.gate == "gate4", 'gateType'] = 3

df3.loc[df3.gate == "general-gate7", 'gateType'] = 2

df3.loc[df3.gate == "ranger-stop7", 'gateType'] = 4

df3.loc[df3.gate == "gate7", 'gateType'] = 3

df3.loc[df3.gate == "gate6", 'gateType'] = 3

df3.loc[df3.gate == "ranger-stop6", 'gateType'] = 4

df3.loc[df3.gate == "gate5", 'gateType'] = 3

df3.loc[df3.gate == "general-gate6", 'gateType'] = 2

df3.loc[df3.gate == "camping7", 'gateType'] = 5

df3.loc[df3.gate == "entrance3", 'gateType'] = 1

df3.loc[df3.gate == "ranger-base", 'gateType'] = 12


df3.loc[df3.gate == "gate8", 'gateType'] = 3


df3.loc[df3.gate == "entrance4", 'gateType'] = 1


df3.loc[df3.gate == "camping6", 'gateType'] = 5




df3.loc[df3.gateType == 5, 'gateTypeName'] = "Camping"
df3.loc[df3.gateType == 4, 'gateTypeName'] = "Ranger-stops"
df3.loc[df3.gateType == 3, 'gateTypeName'] = "Gates"
df3.loc[df3.gateType == 2, 'gateTypeName'] = "General-gates"
df3.loc[df3.gateType == 1, 'gateTypeName'] = "Entrances"

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
df3.to_csv('processedData.csv')
# !cp processedData.csv "drive/My Drive/Tufts"
